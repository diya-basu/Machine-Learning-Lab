# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.model_selection

# %%
#21BAI1926 QUESTION 1: IMPORTING THE DATASET AND READING THE VALUES

# %%
data=pd.read_csv('heart_classification.csv')
data.head(10)
# Out:
#    age     sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3     145.0  233.0    1        0    150.0      0      2.3
# 1   37    male   2     130.0  250.0    0        1    187.0      0      3.5
# 2   41  female   1     130.0  204.0    0        0    172.0      0      1.4
# 3   56    male   1     120.0  236.0    0        1    178.0      0      0.8
# 4   57  female   0       NaN  354.0    0        1    163.0      1      0.6
# 5   57    male   0     140.0  192.0    0        1    148.0      0      0.4
# 6   56  female   1     140.0  294.0    0        0    153.0      0      1.3
# 7   44    male   1     120.0  263.0    0        1    173.0      0      0.0
# 8   52    male   2     172.0  199.0    1        1    162.0      0      0.5
# 9   57    male   2     150.0  168.0    0        1    174.0      0      1.6
#
#    slope  ca  thal target
# 0      0   0     1    yes
# 1      0   0     2    yes
# 2      2   0     2    yes
# 3      2   0     2    yes
# ...

# %%
#21BAI1926 2.checking for missing values
data.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps     True
# chol         True
# fbs         False
# restecg     False
# thalach      True
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
data['trestbps'].fillna(data['trestbps'].mean(),inplace=True)

# %%
data.head()
# Out:
#    age     sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3     145.0  233.0    1        0    150.0      0      2.3
# 1   37    male   2     130.0  250.0    0        1    187.0      0      3.5
# 2   41  female   1     130.0  204.0    0        0    172.0      0      1.4
# 3   56    male   1     120.0  236.0    0        1    178.0      0      0.8
# 4   57  female   0       0.0  354.0    0        1    163.0      1      0.6
#
#    slope  ca  thal target
# 0      0   0     1    yes
# 1      0   0     2    yes
# 2      2   0     2    yes
# 3      2   0     2    yes
# 4      2   0     2    yes

# %%
data.isnull().any()   #all null values successfully removed
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
df=pd.read_csv('heart_classification.csv')

# %%
df['trestbps'].fillna(df['trestbps'].mean(),inplace=True)

# %%
minbp=df['trestbps'].min()
maxbp=df['trestbps']
zulu=maxbp/minbp
print(zulu)
data['Zulu team counts']=zulu
# Out:
# 0      1.542553
# 1      1.382979
# 2      1.382979
# 3      1.276596
# 4      1.401195
#          ...
# 298    1.489362
# 299    1.170213
# 300    1.531915
# 301    1.401195
# 302    1.382979
# Name: trestbps, Length: 303, dtype: float64

# %%
data.head()
# Out:
#    age     sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3     145.0  233.0    1        0    150.0      0      2.3
# 1   37    male   2     130.0  250.0    0        1    187.0      0      3.5
# 2   41  female   1     130.0  204.0    0        0    172.0      0      1.4
# 3   56    male   1     120.0  236.0    0        1    178.0      0      0.8
# 4   57  female   0       0.0  354.0    0        1    163.0      1      0.6
#
#    slope  ca  thal target  Zulu team counts
# 0      0   0     1    yes          1.542553
# 1      0   0     2    yes          1.382979
# 2      2   0     2    yes          1.382979
# 3      2   0     2    yes          1.276596
# 4      2   0     2    yes          1.401195

# %%
df.fillna(0.0,inplace=True)
df['xulu team']=zulu

# %%
#Lowest counts in blood pressure: 
min=zulu.min()
count=0
for i in zulu:
    if(i==min):
        count=count+1
print("Members of the Zulu team having the minimum number of bp:", count)
# Out:
# Members of the Zulu team having the minimum number of bp: 2

# %%
#visualising dashboard of relations between the different attributes given in the heart classification table

# %%
sns.pairplot(data=df)

# %%
#visulaising bmi with stress level
plt.scatter(df['oldpeak'],df['restecg']) 
plt.xlabel('bmi')
plt.ylabel('stress level')
plt.show()

# %%
#dropping records with less quality of sleep

# %% [markdown]
# Problem statement : here we are going to apply the process of Linear Regression to check how Trestbps is connected to the level of cholestrol in the blood. Our main aim will be: given a trestbps value we should be able to predict the approximate cholestrol in the blood

# %%
dta=pd.DataFrame(df,columns=['trestbps','chol'])

# %%
X=dta['trestbps']

# %%
X
# Out:
# 0      145.000000
# 1      130.000000
# 2      130.000000
# 3      120.000000
# 4      131.712375
#           ...
# 298    140.000000
# 299    110.000000
# 300    144.000000
# 301    131.712375
# 302    130.000000
# Name: trestbps, Length: 303, dtype: float64

# %%
Y=dta.iloc[:,-1]

# %%
Y
# Out:
# 0      233.0
# 1      250.0
# 2      204.0
# 3      236.0
# 4      354.0
#        ...
# 298    241.0
# 299    264.0
# 300    193.0
# 301    131.0
# 302    236.0
# Name: chol, Length: 303, dtype: float64

# %%
X.shape
# Out:
# (303,)

# %%
Y.shape
# Out:
# (303,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# 132    120.0
# 202    150.0
# 196    150.0
# 75     135.0
# 176    117.0
#        ...
# 188    140.0
# 71      94.0
# 106    160.0
# 270    120.0
# 102    140.0
# Name: trestbps, Length: 242, dtype: float64

# %%
x_train.shape
# Out:
# (242,)

# %%
y_train
# Out:
# 132    295.0
# 202    270.0
# 196    231.0
# 75     250.0
# 176    230.0
#        ...
# 188    233.0
# 71     227.0
# 106    234.0
# 270    249.0
# 102    195.0
# Name: chol, Length: 242, dtype: float64

# %%
from sklearn.linear_model import LinearRegression,LogisticRegression

# %%
lm=LinearRegression()

# %%
lg=LogisticRegression()

# %%
plt.scatter(X,Y)

# %%
lm.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\admin\Desktop\Diya Basu_21BAI1926\FATLAB.IPYNB Cell 37 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Desktop/Diya%20Basu_21BAI1926/FATLAB.IPYNB#X56sZmlsZQ%3D%3D?line=0'>1</a> lm.fit(x_train,y_train)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:684, in LinearRegression.fit(self, X, y, sample_weight)
#     680 n_jobs_ = self.n_jobs
#     682 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 684 X, y = self._validate_data(
#     685     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686 )
#     688 sample_weight = _check_sample_weight(
#     689     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     690 )
#     692 X, y, X_offset, y_offset, X_scale = _preprocess_data(
# ...

# %%
lg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\admin\Desktop\Diya Basu_21BAI1926\FATLAB.IPYNB Cell 38 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Desktop/Diya%20Basu_21BAI1926/FATLAB.IPYNB#X61sZmlsZQ%3D%3D?line=0'>1</a> lg.fit(x_train,y_train)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:1138, in LogisticRegression.fit(self, X, y, sample_weight)
#    1135 else:
#    1136     _dtype = [np.float64, np.float32]
# -> 1138 X, y = self._validate_data(
#    1139     X,
#    1140     y,
#    1141     accept_sparse="csr",
#    1142     dtype=_dtype,
#    1143     order="C",
#    1144     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1145 )
#    1146 check_classification_targets(y)
#    1147 self.classes_ = np.unique(y)
#
# ...

# %%
y_predict=lm.predict(x_test)
